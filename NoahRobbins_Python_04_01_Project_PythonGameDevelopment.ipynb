# %% [markdown]
# <h3 style="color:red"> THIS COPY IS FILLED OUT</h3>

# %% [markdown]
# <h1 style="text-align:center; font-size: 5em;">Project: Python Game Development</h1>
# <hr style="border:2px solid">
# <h1 style="text-align:center; font-size: 3em;">Project Overview</h1>
# <hr style="border-top:1px dashed">
#
#
# ## Welcome to the First Python Project!
#
# Create a simple and interactive game using Python, incorporating fundamental programming concepts and Python basics. This project aims to reinforce your understanding of core Python principles while fostering creativity through game development.
#
# ### Game options:
#
# #### Guess the Number:
#
# The computer randomly selects a number, and the player has to guess it.
# Provide hints like "too high" or "too low" after each guess.
# Include a limited number of attempts and a score system based on accuracy.
#
# #### Hangman:
#
# Create a word bank and randomly select a word for the player to guess.
# Display the current state of the word with blanks for unrevealed letters.
# Allow a limited number of incorrect guesses before the game ends.
#
# #### Tic-Tac-Toe:
#
# Implement a two-player Tic-Tac-Toe game.
# Ensure proper input validation and display the game board after each move.
# Declare the winner or a draw when the game concludes.
#
# #### Snake Game:
#
# Develop a classic Snake game using the console.
# Control the snake with arrow keys, and let it grow longer with each food item.
# Implement collision detection and keep track of the score.
#
# __Note: you can explore implementiong any other game of your choice.__
#
#
# ## Requirements
#
# This project has two types of requirements:
#
# ### Technical Requirements:
# Technical Requirements are designed to guide you on your project. These will help point you in the right direction as well as show you what we will be looking for when reviewing your project. These requirements will be focused towards the specific coding aspects you use.
#
# ### Functional Requirements:
# Functional Requirements are designed to provoke thought throughout your project. These will be based in theory rather than code. These requirements will assist in shaping your output of each task.
#
# #### Make sure to read all of the instructions at least twice.
#
# <hr style="border:2px solid">
# <h1 style="text-align:center; font-size: 3em;">Project Requirements</h1>
# <hr style="border-top:1px dashed">
#
# ### Functional Requirements:
#
# - Use functions to modularize your code and promote code readability.
# - Implement proper error handling for user inputs to avoid crashes.
# - Ensure the game provides clear instructions and feedback to the player.
# - Add comments to explain complex sections of your code.
# - Create a README file that includes instructions on how to play the game.
#
# __Optional:__
#
# - Implement a graphical user interface (GUI) using libraries like Pygame or Tkinter.
# - Add sound effects or background music to enhance the gaming experience.
# - Create additional levels or features to make the game more challenging.
#
# ### Code Requirements:
#
# This project will require an assortment of counter variables that will have to be set on a global scale (they exist outside of all functions). It will also be required to use at least two function that you write. I would recommend you create the barebones of the game, then pretty it up. Do not worry about making incredibly detailed print statements and formatting until you finish the base game.
#
# - Provide pseudocode and/or flowchart
# - Write at least Two function
# - Check the user input for any types of non-numeric answers or those that are not expected by the program (when applicable)
# - Use several global counters to keep track of user's statistics
# - Incorporate a Graphic User Interface (GUI)
# - Code must have comment's explaining what you did following coding style standars and documentaton best practices
#
#
#
# <hr style="border:2px solid">

# %% [markdown]
# ---
#
# ### Part One:
# > Please provide the Flowchart or pseudocode of your solution.
#
# > These do not need to be overly detailed. Create basic short steps.

# %% [raw]
# Define a list of colors and a dictionary mapping colors to corresponding emoji symbols.
# Define global variables for tracking game statistics.
# Define functions:
#     Generate a random combination of colors.
#     Get player guesses.
#     Print available colors.
# Print game instructions and rules.
# Start a game loop:
#     Generate a four-digit secret code of random colors.
#         Loop for a fixed number of rounds (Mastermind has 8 rounds of guessing):
#             Clear the output after two rounds and print previous guesses for players to compare guesses to.
#             Prompt the player for their guess, validate it, and store it.
#             Count the number of correct colors in correct positions (green ticks) and correct colors in wrong positions (grey ticks).
#             Store the current guess and hints.
#             Print the current guess and hints.
#             Check if the player has won the game by matching all colors in correct positions.
#         If the player hasn't won, continue to the next round.
#     If the player runs out of guesses, end the game and reveal the correct sequence.
#     Ask the player if they want to play again. If yes, continue the game loop; if no, exit the loop.
# Calculate game statistics, including the total number of guesses, the number of incorrect guesses, and the average number of incorrect guesses.
# Print game statistics.

# %% [markdown]
# ---
#
# ### Part Two:
# > Build it!
#
# > Write your code below.
#
# > Work towards a minimal viable product before working on making your output pretty.

# %%
import random #imported random library to generate random colours 
from IPython.display import clear_output #imported IPython.display library to clear outputs later

#list of colours and dictionary of corresponding emojis
colours = ['red', 'white', 'purple', 'blue', 'orange', 'yellow']
dots = {'red': "\U0001F534", 'white': "\u26AA", 'purple': "\U0001F7E3", 'blue': "\U0001F535", 'orange': "\U0001F7E0", 'yellow': "\U0001F7E1"}

#Global variables to use as stats at the end
count = 0
incorrect_guess = []
avg_incorrect = 0

# Function to generate a random combination of colors
def generate_random():
    '''
    Generates random combination of colours using random library.

    Returns: list containing the four colours
    '''
    combination = []
    for i in range(4):
        random_colour = random.choice(colours)
        combination.append(random_colour)
    return combination

# Function to get user guess
def get_player_guess():
    '''
    Asks user to input their guess and validates it in lower case

    Returns: string of user's guess
    '''
    while True:
        guess = input("Your guess: ").lower()
        if guess in colours:
            return guess
        else:
            print("Incorrect input, please choose a colour from the options provided above.")

# Function to print all available colours
def print_all_colours():
    '''
    Prints all availale colours with corresponding emojis from dictionary.
    '''
    for key, value in dots.items():
        print(value, end=' ')

#prints introduction message and reminds users of the rules if they haven't read the instructions (README File)
print_all_colours(), print_all_colours(), print_all_colours(), print_all_colours()
print("\nWELCOME! Are you the Mastermind? Let's play to find out...")
print("Choose 4 colours. You will be shown symbols which hint at the answer after each round of guesses.")
print("A colour in the correct position:✅")
print("A correct colour in the wrong position:☑")
print("No symbols indicate that none of your colours are correct")
print("Input ONE of the following colours: red, white, purple, blue, orange, yellow")

#Game loop begins - used a while loop so that the game will continue to run unless stopped at the end
while True:
    store = []  # Stores all guesses for the current game (within while loop)
    combination = generate_random()  # Calls the function to generate secret code 

    for i in range(8): #length of game is 8 guesses
        count += 1 #adds to global variable count
        if i >= 2:  # After 2 rounds of guessing the output is cleared so that player can focus on the current and previous output only
            clear_output(wait=True)  #calling the IPython.display library
            print("\nPrevious Guesses:") 
            print("Options: red, white, purple, blue, orange, yellow") #prints options again in case user forgets colours
            if len(store) > 0:  # if there are elements in the store then it will print the corresponding emoji for the guess
                for guess, hint in store:
                    print(' '.join(dots[color] for color in guess) + ' ' + ' '.join(hint))
        
        print("\nYou have {} guesses remaining".format(8 - i)) #prints number of guesses remaining

        all_guesses = []  #variable to contain the lists of guesses

        for x in range(4): #stores all the guesses in the list 
            guess = get_player_guess()
            all_guesses.append(guess)

        # counts all the colours in the correct positions (green ticks). Sum +1 for each time this is true (list comprehension)
        correct_positions = sum(1 for i in range(4) if all_guesses[i] == combination[i])
            

        # counts for correct colors in wrong positions (grey ticks)
        #only want to count each colour once so a min is used to prevent double counting
        correct_colors = sum(min(all_guesses.count(color), combination.count(color)) for color in colours) - correct_positions

        #green tick multiplied by number of correct answers and grey tick multiplies by correct colours in wrong place
        hint = ["✅"] * correct_positions + ["☑"] * correct_colors

        store.append((all_guesses, hint))  # Add the current guess and its hint to the store for stacking later

        
        # Print the current guess and ticks
        print("Current Guess:", ' '.join(dots[color] for color in all_guesses))
        print("Hints:", ' '.join(hint))
        
        #Winning
        if correct_positions == 4:
            print("YOU WIN, YOU ARE THE MASTERMIND!!!")
            break
        else:
            for number, colour in enumerate(all_guesses): #counting the incorrect guesses by collecting all guesses and counting them individually (enumerate)
                if colour not in combination: #if statement to identify incorrect values
                    incorrect_guess.append((i + 1, colour)) #stored incorrect values
    #Losing
    else:
        print("You've run out of guesses! Game over. You are not the Mastermind.") 
    #Reveal the results to the loser
    print("Correct Sequence:", ' '.join(dots[color] for color in combination))
    
    #option to play again
    play_again = input("Do you want to play again? (yes/no): ").lower()
    if play_again == "no": #if no then the game loop is broken
        break
    if play_again == "yes": #if yes then the game will continue until they lose
        continue
    else:
        print("Please type yes or no") #ensure they only type yes or no

#calculates average incorrect guesses out of total guesses
avg_incorrect = len(incorrect_guess) / float(count)

#game stats
print("\nGame Stats")
print("Total Guesses:", count)
print("Incorrect Guesses:", len(incorrect_guess))
print("Average of incorrect guesses:", avg_incorrect)
# Out:
# 🔴 ⚪ 🟣 🔵 🟠 🟡 🔴 ⚪ 🟣 🔵 🟠 🟡 🔴 ⚪ 🟣 🔵 🟠 🟡 🔴 ⚪ 🟣 🔵 🟠 🟡
# WELCOME! Are you the Mastermind? Let's play to find out...
# Choose 4 colours. You will be shown symbols which hint at the answer after each round of guesses.
# A colour in the correct position:✅
# A correct colour in the wrong position:☑
# No symbols indicate that none of your colours are correct
# Input ONE of the following colours: red, white, purple, blue, orange, yellow
#
# You have 8 guesses remaining
